# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepakSaini01/FlyRank-AI-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/DeepakSaini01/FlyRank-AI-internship
# Out:
# Cloning into 'FlyRank-AI-internship'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 187 (delta 87), reused 100 (delta 34), pack-reused 0 (from 0)
# Receiving objects: 100% (187/187), 1.88 MiB | 14.73 MiB/s, done.
# Resolving deltas: 100% (87/87), done.

# %%
# %cd /content/FlyRank-AI-internship
# Out:
# /content/FlyRank-AI-internship

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DeepakSaini01/ML-WEEK-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Lane 1 – Ranking Signal Analysis
# I pick this lane because it lets me **understand which observable search signals (impressions, CTR, position, competition, etc.) are most strongly associated with page performance**.
# The answer is useful right away: it tells product and content teams which metrics they should watch when prioritising pages for review, without having to build a complex model first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Check the shape of our starter dataset to confirm setup

import pandas as pd
data_path = "data/raw/content_refresh_anonymized.csv"
try:
    df = pd.read_csv(data_path)
    # The CSV stores the trend direction in `trend_direction`
    # Create the binary label: 1 = declining, 0 = otherwise
    df["is_declining_label"] = (df["trend_direction"] == "down").astype(int)
    print(f"✅ Dataset loaded – rows: {df.shape[0]:,}, columns: {df.shape[1]}")
except Exception as e:
    print(f"❌ Error loading data: {e}")
# Out:
# ✅ Dataset loaded – rows: 30,000, columns: 45

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Decision** – Which pages should a content reviewer prioritize for a quick “title / meta‑description” fix (or other low‑effort SEO improvement)?
#
# **Action** – The reviewer opens the page, updates the title and/or meta description to better match the search intent, and republishes the page.
#
# **Cost of a wrong call** – If a page is incorrectly flagged as high priority, the reviewer spends ≈ 15 minutes on a page that does not need a change, wasting editorial capacity.
#
# If a truly risky page is missed, the missed traffic could be hundreds of clicks per month, translating to lost user engagement and revenue for the client.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Let's check the first few column names to verify what basic metrics we have

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Pulling basic numbers from our loaded dataset





df['is_declining_label'] = (df['trend_direction'] == 'down').astype(int)

# -----------------------------------------------------------------
# 1️⃣ Total number of pages (rows)
# -----------------------------------------------------------------
print(f"🔢 Total pages (rows)            : {len(df):,}")

# -----------------------------------------------------------------
# 2️⃣ Average Click‑Through‑Rate across all pages
# -----------------------------------------------------------------
print(f"📈 Average CTR (overall)         : {df['ctr'].mean():.2%}")

# -----------------------------------------------------------------
# 3️⃣ Proportion of pages currently labelled as “declining”
# -----------------------------------------------------------------
print(f"📉 % pages with trend_direction = 'down' : {df['is_declining_label'].mean():.1%}")
# Out:
# 🔢 Total pages (rows)            : 30,000
# 📈 Average CTR (overall)         : 51.07%
# 📉 % pages with trend_direction = 'down' : 54.2%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# **What we can claim** – We *observed* statistical relationships between safe, historical signals (impressions, CTR, position, competition, content age, etc.) and the binary label `is_declining_label`.
#
#   The correlations and the simple model are descriptive; they tell us which signals tend to appear on pages that are currently trending down.
#
# * **What we cannot claim** – We do **not** prove any causal effect. Changing a signal (e.g., improving CTR by editing a title) does **not** guarantee the page will stop declining.
#   The analysis

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Final validation to confirm our file environment runs cleanly top-to-bottom

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
